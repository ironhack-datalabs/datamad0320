# %% [markdown]
# ## Challenge 2: Sets
#
# There are a lot to learn about Python Sets and the information presented in the lesson is limited due to its length. To learn Python Sets in depth you are strongly encouraged to review the W3Schools tutorial on [Python Sets Examples and Methods](https://www.w3schools.com/python/python_sets.asp) before you work on this lab. Some difficult questions in this lab have their solutions in the W3Schools tutorial.
#
# #### First, import the Python `random` libary

# %%
import random

# %% [markdown]
# #### In the cell below, create a list named `sample_list_1` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * Each value in the list is unique.
#
# Print `sample_list_1` to review its values
#
# *Hint: use `random.sample` ([reference](https://docs.python.org/3/library/random.html#random.sample)).*

# %%
sample_list_1 = random.sample(range(101), k = 80)
print(sample_list_1)
# Out:
# [26, 0, 2, 68, 67, 63, 21, 91, 12, 22, 58, 32, 76, 15, 27, 59, 31, 35, 57, 54, 19, 56, 78, 20, 39, 44, 98, 99, 5, 89, 52, 24, 71, 7, 8, 85, 4, 3, 45, 83, 42, 28, 11, 33, 79, 69, 6, 18, 61, 47, 82, 100, 86, 96, 9, 93, 72, 95, 30, 74, 94, 66, 29, 70, 55, 51, 53, 14, 73, 13, 48, 84, 81, 46, 64, 88, 87, 60, 97, 17]

# %% [markdown]
# #### Convert `sample_list_1` to a set called `set1`. Print the length of the set. Is its length still 80?

# %%
set1 = set(sample_list_1)
print(len(set1))
# Out:
# 80

# %% [markdown]
# #### Create another list named `sample_list_2` with 80 random values.
#
# Requirements:
#
# * Each value is an integer falling between 0 and 100.
# * The values in the list don't have to be unique.
#
# *Hint: Use a FOR loop.*

# %%
sample_list_2 = []

#Usamos un for loop sobre un rango de 0:79 y por cada iteración añadimos a la lista un número al azar del 1 al 100.
for e in range(80):
    rnd = random.sample(range(101), k = 1)
    #Añadimos un indice a rnd porque el output de la función sample es una lista (una lista de 1 elemento en este caso) 
    sample_list_2.append(rnd[0])

print(len(sample_list_2))
# Out:
# 80

# %% [markdown]
# #### Convert `sample_list_2` to a set called `set2`. Print the length of the set. Is its length still 80?

# %%
set2 = set(sample_list_2)
print(len(set2))

#La longitud del set2 es menor porque los set no guardan valores repetidos.
# Out:
# 57

# %% [markdown]
# #### Identify the elements present in `set1` but not in `set2`. Assign the elements to a new set named `set3`.

# %%
set3 = set1.difference(set2)
print(set3)
# Out:
# {0, 3, 4, 5, 6, 8, 13, 26, 27, 29, 30, 31, 35, 42, 44, 46, 52, 55, 56, 57, 60, 61, 67, 72, 73, 81, 82, 85, 86, 88, 89, 96, 97, 98, 99, 100}

# %% [markdown]
# #### Identify the elements present in `set2` but not in `set1`. Assign the elements to a new set named `set4`.

# %%
set4 = set2.difference(set1)
print(set4)
# Out:
# {1, 34, 36, 37, 40, 41, 10, 43, 16, 49, 50, 25, 92}

# %% [markdown]
# #### Now Identify the elements shared between `set1` and `set2`. Assign the elements to a new set named `set5`.

# %%
set5 = set1.intersection(set2)
print(set5)
# Out:
# {2, 7, 9, 11, 12, 14, 15, 17, 18, 19, 20, 21, 22, 24, 28, 32, 33, 39, 45, 47, 48, 51, 53, 54, 58, 59, 63, 64, 66, 68, 69, 70, 71, 74, 76, 78, 79, 83, 84, 87, 91, 93, 94, 95}

# %% [markdown]
# #### What is the relationship among the following values:
#
# * len(set1)
# * len(set2)
# * len(set3)
# * len(set4)
# * len(set5)
#
# Use a math formular to represent that relationship. Test your formular with Python code.

# %%
print(len(set1), len(set2), len(set3), len(set4), len(set5))

#La longitud de el set1 es la suma de las diferencias con el set2 y las similitudes con el set2
print(len(set3) + len(set5) == len(set1))
#De la misma manera La longitud de el set2 es la suma de las diferencias con el set1 y las similitudes con el set1
print(len(set4) + len(set5) == len(set2))
# Out:
# 80 57 36 13 44
# True
# True

# %% [markdown]
# #### Create an empty set called `set6`.

# %%
set6 = set()

# %% [markdown]
# #### Add `set3` and `set5` to `set6` using the Python Set `update` method.

# %%
#Aquí intenté primero hacer un doble update (set6.update(set3.update(set5))), pero no funcionó. 
#Además, si no me equivoco, no sería correcto porque estaría modificando set3 a la vez

set6.update(set3)
set6.update(set5)
print(set3)
# Out:
# {0, 3, 4, 5, 6, 8, 13, 26, 27, 29, 30, 31, 35, 42, 44, 46, 52, 55, 56, 57, 60, 61, 67, 72, 73, 81, 82, 85, 86, 88, 89, 96, 97, 98, 99, 100}

# %% [markdown]
# #### Check if `set1` and `set6` are equal.

# %%
#Como los sets no tienen orden, podemos compararlos directamente sin importarnos cual es su orden
set1 == set6
# Out:
# True

# %% [markdown]
# #### Check if `set1` contains `set2` using the Python Set `issubset` method. Then check if `set1` contains `set3`.*

# %%
#Contiene el set1 a el set2
print(set2.issubset(set1))
#Contiene el set3 al set1
print(set3.issubset(set1))
# Out:
# False
# True

# %% [markdown]
# #### Using the Python Set `union` method, aggregate `set3`, `set4`, and `set5`. Then aggregate `set1` and `set2`.
#
# #### Check if the aggregated values are equal.

# %%
print(set3.union(set4, set5) == set1.union(set2))
# Out:
# True

# %% [markdown]
# #### Using the `pop` method, remove the first element from `set1`.

# %%
pop = set1.pop()
#Puesto que los sets no tienen order no sabemos realmente de donde quitamos el elemento
print(pop)
# Out:
# 0

# %% [markdown]
# #### Remove every element in the following list from `set1` if they are present in the set. Print the remaining elements.
#
# ```
# list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]
# ```

# %%
list_to_remove = [1, 9, 11, 19, 21, 29, 31, 39, 41, 49, 51, 59, 61, 69, 71, 79, 81, 89, 91, 99]

#print(set1)
#Uso la función discard() que no lanza errores si el elemento no existe en el set
for e in list_to_remove:
    set1.discard(e)
print(set1)
# Out:
# {2, 3, 4, 5, 6, 7, 8, 12, 13, 14, 15, 17, 18, 20, 22, 24, 26, 27, 28, 30, 32, 33, 35, 42, 44, 45, 46, 47, 48, 52, 53, 54, 55, 56, 57, 58, 60, 63, 64, 66, 67, 68, 70, 72, 73, 74, 76, 78, 82, 83, 84, 85, 86, 87, 88, 93, 94, 95, 96, 97, 98, 100}
