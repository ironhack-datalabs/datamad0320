# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1)
plt.plot(x, y, lw = 2, color = "blue", ls='-')
plt.subplot(1,2,2)
plt.plot(x, z, lw = 2, color = "green", ls = '--' )

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
fig, axes = plt.subplots(1,2)
axes[0].plot(x,y,color="b", lw=2, ls='-')
axes[1].plot(x,z,color="g", lw=2, ls='--')

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
fig, axes = plt.subplots(1,2, figsize=(8, 5))
axes[0].plot(x,y,color="b", lw=2, ls='-')
axes[1].plot(x,z,color="g", lw=2, ls='--')

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
fig, axes = plt.subplots(1,2, figsize=(14, 5))
axes[0].plot(x,y,color="b", lw=2, ls='-')
axes[0].set_xlabel('Días de confinamiento')
axes[0].set_ylabel('Ganas de tomar una cerveza fuera')
axes[1].plot(x,z,color="g", lw=2, ls='--')
axes[1].set_xlabel('Días de confinamiento')
axes[1].set_ylabel('Ganas de matar a los compañer@s de piso')
# Out:
# Text(0, 0.5, 'Ganas de matar a los compañer@s de piso')

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
# your code here
fig, axes = plt.subplots(1,2, figsize=(14, 5))
axes[0].plot(x, x**2, x, np.exp(x))
axes[0].set_xscale('linear')
axes[0].set_yscale('linear')
axes[1].plot(x, x**2, x, np.exp(x))
axes[0].set_xscale('log')
axes[0].set_yscale('log')

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
df = pd.read_csv("vehicles.csv")

# %%
plt.scatter(df[["Combined MPG"]], df[["Highway MPG"]])
plt.xlabel("Combined MPG")
plt.ylabel("Highway MPG")
# Out:
# Text(0, 0.5, 'Highway MPG')

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
df.boxplot(column='CO2 Emission Grams/Mile', vert=False)

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here
df[["Fuel Barrels/Year"]].plot.hist()

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
barplot = df.plot.bar(x='Fuel Type', y='City MPG')
# Out:
# Error in callback <function flush_figures at 0x7f985a151550> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
fig, ax = plt.subplots()
plt.bar(df['Fuel Type'], df['City MPG'])
